# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/warn.csv')

# %%
df.head()
# Out:
#   notice_date event_number                   reason  \
# 0   4/30/2020    2019-1376   Temporary Plant Layoff
# 1   4/30/2020    2019-1187             Plant Layoff
# 2    5/4/2020    2019-0278             Plant Layoff
# 3    5/1/2020    2019-1214  Temporary Plant Closing
# 4   4/30/2020    2019-0377            Plant Closing
#
#                                              company  \
# 0                           Cast & Crew Payroll, LLC
# 1                    Michael Page International Inc.
# 2  Jamestown Metal Products LLC, a division of In...
# 3                    Westbury Manor Enterprises Inc.
# 4                              Altman Lighting, Inc.
#
#                                           address              county  \
# 0       7 Penn Plaza, Suite 601New York, NY 10001     New York County
# 1  622 Third Avenue, 29th FloorNew York, NY 10017     New York County
# 2        178 Blackstone AvenueJamestown, NY 14701   Chautauqua County
# ...

# %%
df.tail()
# Out:
#      notice_date event_number                   reason  \
# 1231    1/8/2020    2019-0210            Plant Closing
# 1232    1/6/2020    2019-0207            Plant Closing
# 1233  12/27/2019    2019-0206  Temporary Plant Closing
# 1234  12/30/2019    2019-0205            Plant Closing
# 1235  12/30/2019    2019-0201            Plant Closing
#
#                                                 company  \
# 1231                 Connected Ventures, LLC (CH Media)
# 1232  Macy's Broadway Mall Store (Macy's Retail Hold...
# 1233                        Wesley Gardens Nursing Home
# 1234  127 W. 43rd St. Chophouse, Inc. (Heartland Bre...
# 1235                New York Express and Logistics, LLC
#
#                                               address           county  \
# 1231  330 W. 34th Street, 5th FloorNew York, NY 10001  New York County
# 1232            100 Broadway MallHicksville, NY 11801    Nassau County
# 1233                  3 Upton ParkRochester, NY 14607    Monroe County
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   notice_date      1236 non-null   object
#  1   event_number     1236 non-null   object
#  2   reason           1236 non-null   object
#  3   company          1236 non-null   object
#  4   address          1235 non-null   object
#  5   county           1236 non-null   object
#  6   phone            1236 non-null   object
#  7   business_type    1236 non-null   object
#  8   affected         1236 non-null   object
#  9   total_employees  1236 non-null   int64
#  10  layoff_date      1233 non-null   object
#  11  dislocation      1236 non-null   object
#  12  union            1236 non-null   object
#  13  classification   1236 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 135.3+ KB

# %%
df.to_csv('../data/warn_na.csv', index=False)

# %%
df_na = pd.read_csv('../data/warn_na.csv')

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   notice_date      1236 non-null   object
#  1   event_number     1236 non-null   object
#  2   reason           1236 non-null   object
#  3   company          1236 non-null   object
#  4   address          1236 non-null   object
#  5   county           1236 non-null   object
#  6   phone            1236 non-null   object
#  7   business_type    1236 non-null   object
#  8   affected         1236 non-null   object
#  9   total_employees  1236 non-null   int64
#  10  layoff_date      1236 non-null   object
#  11  dislocation      1236 non-null   object
#  12  union            1236 non-null   object
#  13  classification   1236 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 135.3+ KB

# %%
df = df.fillna(0)

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   notice_date      1236 non-null   object
#  1   event_number     1236 non-null   object
#  2   reason           1236 non-null   object
#  3   company          1236 non-null   object
#  4   address          1236 non-null   object
#  5   county           1236 non-null   object
#  6   phone            1236 non-null   object
#  7   business_type    1236 non-null   object
#  8   affected         1236 non-null   object
#  9   total_employees  1236 non-null   int64
#  10  layoff_date      1236 non-null   object
#  11  dislocation      1236 non-null   object
#  12  union            1236 non-null   object
#  13  classification   1236 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 135.3+ KB

# %%
#Which kind of reasons of WARN notifications were the most?
df_na['reason'].unique()
# Out:
# array(['Temporary Plant Layoff', 'Plant Layoff',
#        'Temporary Plant Closing', 'Plant Closing', 'Plang Closing',
#        'Temporary Layoff', 'Temporary Plant Closing and Plant Closing',
#        'Temporary & Permanent Layoff', 'Temporary Plant \nClosing',
#        'Temporary Plant \nLayoff',
#        'Temporary Plant Layoff and Plant Closing',
#        'Temporary Reduction in Work Hours',
#        'Temporary Plant Layoff/Plant Layoff',
#        'Temporary Plant Layoff (Furlough)', 'Plant Layoff (Conditional)',
#        'Temporary PLant Layoff', 'Temporary PlantClosing',
#        'Temporary Closing', 'Possible Plant Layoff/Closing',
#        'Temporary Palnt Closing', 'Plant Temporary Closing', 'Plant Sale',
#        'Contract Dissolution', 'Plant Unit Closing',
#        'Tempoarary Plant Closing', 'Plant Relocation',
#        'Partial Temporary Closing', 'Temporary Plant Layoff/Closing',
#        'Plant Demolition', 'Temporary Partial Plant Closing',
# ...

# %%
Reason = df_na['reason'].value_counts()
Reason
# Out:
# Temporary Plant Layoff                       604
# Temporary Plant Closing                      463
# Plant Closing                                 83
# Plant Layoff                                  73
# Plant Relocation                               1
# Contract Dissolution                           1
# Temporary Partial Plant Closing                1
# Temporary Plant Closing/Layoff                 1
# Plant Sale                                     1
# Temporary Plant Layoff and Plant Closing       1
# Plang Closing                                  1
# Temporary Plant Closing and Plant Closing      1
# Plant Demolition                               1
# Temporary & Permanent Layoff                   1
# Temporary Plant Layoff/Closing                 1
# Temporary Reduction in Work Hours              1
# Possible Plant Layoff/Closing                  1
# Name: reason, dtype: int64

# %%
df.loc[df['reason'].isin(['Temporary PlantClosing', 
                          'TemporaryPlant Closing', 
                          'Temporary Plant \nClosing',
                          'Temporary Plant  Closing',
                          'Temporary Palnt Closing',
                          'Temporary Closing',
                          'Temporary  Plant Closing', 
                          'Temporary Unit Closing',
                          'Plant Temporary Closing',
                          'Temporary Plant Closing and Plant Closing'
                          'Temporary Partial Plant Closing',
                          'Partial Temporary Closing',
                          'Tempoarary Plant Closing']), 'reason'] = 'Temporary Plant Closing' 
df.loc[df['reason'].isin(['Temporary Plant  Layoff', 
                          'Temporary PLant Layoff', 
                          'Temporary  Plant Layoff',
                          'Temporary Plant Layoff/Plant Layoff',
                          'Temporary Plant Layoff (Furlough)',
                          'Temporary Plant \nLayoff',
                          'Temporary Layoff'
                          ]), 'reason'] = 'Temporary Plant Layoff'
df.loc[df['reason'].isin(['Plant Unit Closing']), 'reason'] = 'Plant Closing'
df.loc[df['reason'].isin(['Plant Layoff (Conditional)',
                          'Possible Plant Layoff']), 'reason'] = 'Plant Layoff'

# %%
reasons = df_na['reason'].value_counts().reset_index().rename(columns = {'index': 'reason', 'reason': 'count'})
reasons
# Out:
#                                        reason  count
# 0                      Temporary Plant Layoff    604
# 1                     Temporary Plant Closing    463
# 2                               Plant Closing     83
# 3                                Plant Layoff     73
# 4                            Plant Relocation      1
# 5                        Contract Dissolution      1
# 6             Temporary Partial Plant Closing      1
# 7              Temporary Plant Closing/Layoff      1
# 8                                  Plant Sale      1
# 9    Temporary Plant Layoff and Plant Closing      1
# 10                              Plang Closing      1
# 11  Temporary Plant Closing and Plant Closing      1
# 12                           Plant Demolition      1
# 13               Temporary & Permanent Layoff      1
# 14             Temporary Plant Layoff/Closing      1
# 15          Temporary Reduction in Work Hours      1
# 16              Possible Plant Layoff/Closing      1

# %%
reasons.to_csv('../data/reasons.csv', index=False)

# %%
#Which kind of business types were affected by a WARN notice most? Select>10
df['business_type'].unique()
# Out:
# array(['Payroll & HR Services', 'Employment Agency',
#        'Provide complete source for lab systems and sustainable, adaptable casework of painted steel, wood or stainless steel complete with specified fixtures, fume hoods and work surfaces.',
#        'Restaurant', 'Theatrical, architectural, film and video lighting',
#        'Hotel', 'Commercial Printing', 'American online travel company',
#        'Building maintenance and cleaning services', 'Event Company',
#        'Car cleaning services', 'Realty Management', 'Seafood Restaurant',
#        'All Luxury SUV, Cars, Vans Rentals', 'Car rentals',
#        'Dental equipment distribution and manufacturing',
#        'On-demand car service', 'Renewable Energy Provider',
#        'Event Planners/Caterers', 'Transporation Services',
#        'Quality cleaning and maintenance services', 'Car Rentals',
#        'Transportation', 'Marine Cargo Handling',
#        'Producer of LED safety lighting', 'Car Rental', 'Travel Agency',
# ...

# %%
business_type = df['business_type'].value_counts().reset_index()
business_type
# Out:
#                                   index  business_type
# 0                            Restaurant            482
# 1                                 Hotel            141
# 2                                Retail             39
# 3                       Auto Dealership             24
# 4                              Catering             16
# ..                                  ...            ...
# 358   Accounting and Financial Services              1
# 359                     Airport Support              1
# 360              Transporation Services              1
# 361  Health Care Provider - Mammography              1
# 362                            Day Camp              1
#
# [363 rows x 2 columns]

# %%
business_type.to_csv('../data/business_type.csv', index=False)

# %%
business_type.sort_values("business_type", ascending=False)
# Out:
#                                                  index  business_type
# 0                                           Restaurant            482
# 1                                                Hotel            141
# 2                                               Retail             39
# 3                                      Auto Dealership             24
# 4                                             Catering             16
# ..                                                 ...            ...
# 169                              Human Services Agency              1
# 168                             Online Recommendations              1
# 167  Trucking company providing freight transportat...              1
# 166                                         Youth Club              1
# 362                                           Day Camp              1
#
# [363 rows x 2 columns]

# %%
business_type.head(10)
# Out:
#                    index  business_type
# 0             Restaurant            482
# 1                  Hotel            141
# 2                 Retail             39
# 3        Auto Dealership             24
# 4               Catering             16
# 5               Eye Care             10
# 6      Building Services             10
# 7  Retail clothing store             10
# 8         Transportation              8
# 9                 School              7

# %%
#Which kind of reason for diclocations of WARN notifications were the most? Select>1
dislocations = df_na['dislocation'].value_counts().reset_index().rename(columns={'index': 'dislocation', 'dislocation': 'count'})
dislocations
# Out:
#                                           dislocation  count
# 0   Unforeseeable business circumstances prompted ...   1108
# 1                                            Economic     57
# 2   Unforeseeable  business circumstances prompted...      8
# 3   Unforeseen business circumstances as a result ...      3
# 4   Restructuring which will involve the relocatio...      3
# 5   The Company’s initial temporary layoffs were u...      3
# 6                                    Sale of Business      3
# 7   EconomicUnforeseeable business circumstances p...      2
# 8                                   Budgetary Deficit      2
# 9   Economic and unforeseen business circumstances...      1
# 10  The production work is moving to another compa...      1
# 11                               Sale of the business      1
# 12                             Company Reorganization      1
# 13                                     Reorganization      1
# ...

# %%
dislocations.to_csv('../data/dislocations.csv', index=False)

# %%
dislocations.head(15)
# Out:
#                                           dislocation  count
# 0   Unforeseeable business circumstances prompted ...   1108
# 1                                            Economic     57
# 2   Unforeseeable  business circumstances prompted...      8
# 3   Unforeseen business circumstances as a result ...      3
# 4   Restructuring which will involve the relocatio...      3
# 5   The Company’s initial temporary layoffs were u...      3
# 6                                    Sale of Business      3
# 7   EconomicUnforeseeable business circumstances p...      2
# 8                                   Budgetary Deficit      2
# 9   Economic and unforeseen business circumstances...      1
# 10  The production work is moving to another compa...      1
# 11                               Sale of the business      1
# 12                             Company Reorganization      1
# 13                                     Reorganization      1
# ...

# %%
df_na[df_na.affected != 'To']
# Out:
#      notice_date event_number                   reason  \
# 0      4/30/2020    2019-1376   Temporary Plant Layoff
# 1      4/30/2020    2019-1187             Plant Layoff
# 2       5/4/2020    2019-0278             Plant Layoff
# 3       5/1/2020    2019-1214  Temporary Plant Closing
# 4      4/30/2020    2019-0377            Plant Closing
# ...          ...          ...                      ...
# 1231    1/8/2020    2019-0210            Plant Closing
# 1232    1/6/2020    2019-0207            Plant Closing
# 1233  12/27/2019    2019-0206  Temporary Plant Closing
# 1234  12/30/2019    2019-0205            Plant Closing
# 1235  12/30/2019    2019-0201            Plant Closing
#
#                                                 company  \
# 0                              Cast & Crew Payroll, LLC
# 1                       Michael Page International Inc.
# 2     Jamestown Metal Products LLC, a division of In...
# 3                       Westbury Manor Enterprises Inc.
# ...

# %%
df_na.head(35)
# Out:
#    notice_date           event_number                   reason  \
# 0    4/30/2020              2019-1376   Temporary Plant Layoff
# 1    4/30/2020              2019-1187             Plant Layoff
# 2     5/4/2020              2019-0278             Plant Layoff
# 3     5/1/2020              2019-1214  Temporary Plant Closing
# 4    4/30/2020              2019-0377            Plant Closing
# 5     5/4/2020              2019-1606  Temporary Plant Closing
# 6     5/5/2020              2019-1607            Plant Closing
# 7    4/28/2020              2019-1612             Plant Layoff
# 8    4/15/2020              2019-1613   Temporary Plant Layoff
# 9    4/27/2020              2019-1507   Temporary Plant Layoff
# 10   4/27/2020              2019-1608  Temporary Plant Closing
# 11   4/27/2020              2019-1610  Temporary Plant Closing
# 12   3/27/2020              2019-1614   Temporary Plant Layoff
# 13   4/27/2020              2019-1611  Temporary Plant Closing
# ...

# %%
df_na.groupby(['business_type'])['affected'].agg('sum').sort_values(ascending=False).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-0f1373c157b8> in <module>
# ----> 1 df_na.groupby(['business_type'])['affected'].agg('sum').sort_values(ascending=False).reset_index()
#
# ~/.local/share/virtualenvs/ny-warn-scraper-OZol3r9B/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     245
#     246         if isinstance(func, str):
# --> 247             return getattr(self, func)(*args, **kwargs)
#     248
#     249         elif isinstance(func, abc.Iterable):
#
# ~/.local/share/virtualenvs/ny-warn-scraper-OZol3r9B/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in f(self, **kwargs)
#    1383
#    1384                 # apply a non-cython aggregation
# -> 1385                 result = self.aggregate(lambda x: npfunc(x, axis=self.axis))
#    1386                 return result
#    1387
#
# ...
